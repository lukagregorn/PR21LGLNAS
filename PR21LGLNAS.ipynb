# %% [markdown]
# ## Najpogosteje reakcije na sporočila

# %% [markdown]
# Prikazal vam bom najpogosteje reakcije na sporočila.

# %% [markdown]
# **Priprava podatkov**

# %%
# uporabljene knjižnice
import json
import pandas as pd

# %%
# prvi semester
matematika = json.load(open('DATA/matematika.json', encoding="utf8"))
matematikaDf = pd.DataFrame(matematika["messages"]) 

diskretne = json.load(open('DATA/diskretne-strukture.json', encoding="utf8"))
diskretneDf = pd.DataFrame(diskretne["messages"]) 

programiranje1 = json.load(open('DATA/programiranje-1.json', encoding="utf8"))
programiranje1Df = pd.DataFrame(programiranje1["messages"]) 

uvod = json.load(open('DATA/uvod-v-racunalnistvo.json', encoding="utf8"))
uvodDf = pd.DataFrame(uvod["messages"]) 

arhitektura = json.load(open('DATA/racunalniska-arhitektura.json', encoding="utf8"))
arhitekturaDf = pd.DataFrame(arhitektura["messages"])

# %%
# drugi semester 
komunikacije = json.load(open('DATA/racunalniske-komunikacije.json', encoding="utf8"))
komunikacijeDf = pd.DataFrame(komunikacije["messages"]) 

operacijski = json.load(open('DATA/operacijski-sistemi.json', encoding="utf8"))
operacijskiDf = pd.DataFrame(operacijski["messages"]) 

programiranje2 = json.load(open('DATA/programiranje-2.json', encoding="utf8"))
programiranje2Df = pd.DataFrame(programiranje2["messages"]) 

podatkovneBaze = json.load(open('DATA/podatkovne-baze.json', encoding="utf8"))
podatkovneBazeDf = pd.DataFrame(podatkovneBaze["messages"]) 

statistika = json.load(open('DATA/statistika.json', encoding="utf8"))
statistikaDf = pd.DataFrame(statistika["messages"])

# %% [markdown]
# **Podatki**

# %%
matematikaDf
# Out:
#                        id     type                      timestamp  \
# 0      370228921779748864  Default  2017-10-18T15:17:33.473+00:00
# 1      370228996262199297  Default  2017-10-18T15:17:51.231+00:00
# 2      370229030877659137  Default  2017-10-18T15:17:59.484+00:00
# 3      370229074351751168  Default  2017-10-18T15:18:09.849+00:00
# 4      370229150092492800  Default  2017-10-18T15:18:27.907+00:00
# ...                   ...      ...                            ...
# 28564  816250792734228510  Default  2021-03-02T10:09:14.194+00:00
# 28565  816250806855794730  Default  2021-03-02T10:09:17.561+00:00
# 28566  816250807934517248  Default  2021-03-02T10:09:17.818+00:00
# 28567  816250819891822612  Default  2021-03-02T10:09:20.669+00:00
# 28568  816250820944461834  Default   2021-03-02T10:09:20.92+00:00
#
#       timestampEdited callEndedTimestamp  isPinned  \
# 0                None               None     False
# 1                None               None     False
# ...

# %%
statistikaDf
# Out:
#                        id     type                      timestamp  \
# 0      414783142633930752  Default  2018-02-18T14:00:07.502+00:00
# 1      414783175647035402  Default  2018-02-18T14:00:15.373+00:00
# 2      415050802185633802  Default  2018-02-19T07:43:42.512+00:00
# 3      415050879754829835  Default  2018-02-19T07:44:01.006+00:00
# 4      415050922293723137  Default  2018-02-19T07:44:11.148+00:00
# ...                   ...      ...                            ...
# 59544  822961322928767017  Default  2021-03-20T22:34:29.268+00:00
# 59545  824620702736318484  Default  2021-03-25T12:28:16.244+00:00
# 59546  824666721091715092  Default  2021-03-25T15:31:07.875+00:00
# 59547  824667001653559296  Default  2021-03-25T15:32:14.766+00:00
# 59548  824917063918419979  Default  2021-03-26T08:05:54.256+00:00
#
#       timestampEdited callEndedTimestamp  isPinned  \
# 0                None               None     False
# 1                None               None     False
# ...

# %% [markdown]
# **Priprava reakcij (1. semester)**

# %%
reakcije = {} 

for index, row in matematikaDf.iterrows(): 
    if len(row["reactions"]) != 0:
        for vrstica in row["reactions"]:
            if vrstica['emoji']['name'] not in reakcije:
                reakcije.update({vrstica['emoji']['name'] : 1}) 
            else: 
                reakcije[vrstica['emoji']['name']] += 1

# %%
for index, row in diskretneDf.iterrows(): 
    if len(row["reactions"]) != 0:
        for vrstica in row["reactions"]:
            if vrstica['emoji']['name'] not in reakcije:
                reakcije.update({vrstica['emoji']['name'] : 1}) 
            else: 
                reakcije[vrstica['emoji']['name']] += 1

# %%
for index, row in programiranje1Df.iterrows(): 
    if len(row["reactions"]) != 0:
        for vrstica in row["reactions"]:
            if vrstica['emoji']['name'] not in reakcije:
                reakcije.update({vrstica['emoji']['name'] : 1}) 
            else: 
                reakcije[vrstica['emoji']['name']] += 1

# %%
for index, row in uvodDf.iterrows(): 
    if len(row["reactions"]) != 0:
        for vrstica in row["reactions"]:
            if vrstica['emoji']['name'] not in reakcije:
                reakcije.update({vrstica['emoji']['name'] : 1}) 
            else: 
                reakcije[vrstica['emoji']['name']] += 1

# %%
for index, row in arhitekturaDf.iterrows(): 
    if len(row["reactions"]) != 0:
        for vrstica in row["reactions"]:
            if vrstica['emoji']['name'] not in reakcije:
                reakcije.update({vrstica['emoji']['name'] : 1}) 
            else: 
                reakcije[vrstica['emoji']['name']] += 1

# %%
# reakcije (emoji-i) uporabljeni v prvem semestru 
reakcije
# Out:
# {'😂': 78,
#  '👌': 154,
#  '👌🏻': 7,
#  '🍆': 25,
#  'me_irl2': 45,
#  'me_irl': 25,
#  'tf_do_i_see': 15,
#  'LUL': 54,
#  'weSmart': 132,
#  'thonk': 13,
#  'PEPE': 21,
#  'pepoThink': 28,
#  '4think': 8,
#  '😢': 7,
#  'feelsbadman': 34,
#  '👌🏾': 5,
#  'HAhaa': 60,
#  '😃': 5,
#  '1up': 16,
#  '❤': 40,
#  '👆': 4,
#  '😄': 17,
#  '👍': 153,
#  'Wowee': 33,
#  '🍝': 1,
#  '🛤': 2,
#  'sweatstiny': 25,
#  'haHAA2': 7,
#  'feelsHugMan': 17,
#  '🔴': 4,
#  'everythingokay': 23,
#  'gachiGasm': 20,
#  'reee': 13,
#  'pepehands': 58,
#  'feelsamazingman': 34,
#  'GWcmeisterPeepoEZ': 1,
#  'GWsetmyxPeepoCry': 1,
#  'GWcmeisterPeepoHug': 1,
#  'jew': 4,
#  'GWvertiPeepoChrist': 1,
#  'omegalul': 15,
#  'GWfroggyPeepoDetective': 1,
#  'GWfroggyPepoSmug': 3,
#  'GWfroggyMonkaMega': 1,
#  'GWslippyPeepoW': 1,
#  'GWcmeisterPeepoE': 1,
#  'OoO': 15,
#  'GWcorbinMonkaGIGA': 8,
#  '🇫': 9,
#  'GWqlabsWtf': 1,
#  'angrythonk': 5,
#  'feelsWowMan': 57,
#  'verynice': 69,
#  '👌🏿': 10,
#  'DSBOI': 23,
# ...

# %% [markdown]
# Ker gledamo najpogosteje uporabljene reakcije, sem tiste, ki so uporabljene manj kot 20-krat odstranil, saj ima najpogosteje uporabljena reakcija v tem semestru 157 uporab.

# %%
zbReakcije = {}
for key, value in reakcije.items(): 
    if (value >= 20): 
        if key == '😂':
            zbReakcije.update({':joy:' : value})
        elif key == '👌': 
            zbReakcije.update({':ok:' : value})
        elif key == '🍆': 
            zbReakcije.update({':eggplant:' : value}) 
        elif key == '❤':
            zbReakcije.update({':heart:' : value}) 
        elif key == '👍':
            zbReakcije.update({':thumbsup:' : value}) 
        elif key == '💯':
            zbReakcije.update({':hundredpoints:' : value}) 
        elif key == '✅': 
            zbReakcije.update({':whiteheavycheckmark:' : value}) 
        elif key == '🗑': 
            zbReakcije.update({':wastebasket:' : value}) 
        elif key == '❌': 
            zbReakcije.update({':crossmarkemoji:' : value}) 
        elif key == '❤️': 
            zbReakcije.update({':redheartemoji:' : value}) 
        else: 
            zbReakcije.update({key : value})

# %%
# izboljšan slovar reakcij
zbReakcije
# Out:
# {':joy:': 78,
#  ':ok:': 154,
#  ':eggplant:': 25,
#  'me_irl2': 45,
#  'me_irl': 25,
#  'LUL': 54,
#  'weSmart': 132,
#  'PEPE': 21,
#  'pepoThink': 28,
#  'feelsbadman': 34,
#  'HAhaa': 60,
#  ':heart:': 40,
#  ':thumbsup:': 153,
#  'Wowee': 33,
#  'sweatstiny': 25,
#  'everythingokay': 23,
#  'gachiGasm': 20,
#  'pepehands': 58,
#  'feelsamazingman': 34,
#  'feelsWowMan': 57,
#  'verynice': 69,
#  'DSBOI': 23,
#  ':hundredpoints:': 67,
#  'tipsfedora': 67,
#  ':whiteheavycheckmark:': 82,
#  ':wastebasket:': 35,
#  'GWcorbinHolyFuck': 20,
#  ':crossmarkemoji:': 37,
#  'lekosalute': 157,
#  'kekW': 63,
#  ':redheartemoji:': 28,
#  'Pogomega': 34,
#  'Pogey': 27,
#  'PeepoSad': 50,
#  'kek': 20,
#  'yeeter': 23,
#  'boi': 23,
#  'vro': 28,
#  'lekoyes': 21}

# %% [markdown]
# **Grafični prikaz podatkov**

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

csfont = {'fontname':'DejaVu Sans'}

f, ax = plt.subplots(figsize=(27,25)) 

plt.barh(*zip(*zbReakcije.items()), height=0.7, color="darkgreen") 
vr = 0
for key, value in zbReakcije.items():
    plt.text(value, vr, str(value), fontsize=20)
    vr+=1
plt.title("Porazdelitev reakcij na sporočila (1. semester)", fontsize=40) 
plt.xlabel("Število reakcij", fontsize=30)
plt.ylabel("Reakcija", fontsize=30) 
plt.xticks(fontsize=20, **csfont) 
plt.yticks(fontsize=20)
plt.show()

# %% [markdown]
# **Priprava reakcij (2. semester)**

# %%
reakcije2 = {} 

for index, row in komunikacijeDf.iterrows(): 
    if len(row["reactions"]) != 0:
        for vrstica in row["reactions"]:
            if vrstica['emoji']['name'] not in reakcije2:
                reakcije2.update({vrstica['emoji']['name'] : 1}) 
            else: 
                reakcije2[vrstica['emoji']['name']] += 1

# %%
for index, row in operacijskiDf.iterrows(): 
    if len(row["reactions"]) != 0:
        for vrstica in row["reactions"]:
            if vrstica['emoji']['name'] not in reakcije2:
                reakcije2.update({vrstica['emoji']['name'] : 1}) 
            else: 
                reakcije2[vrstica['emoji']['name']] += 1

# %%
for index, row in programiranje2Df.iterrows(): 
    if len(row["reactions"]) != 0:
        for vrstica in row["reactions"]:
            if vrstica['emoji']['name'] not in reakcije2:
                reakcije2.update({vrstica['emoji']['name'] : 1}) 
            else: 
                reakcije2[vrstica['emoji']['name']] += 1

# %%
for index, row in podatkovneBazeDf.iterrows(): 
    if len(row["reactions"]) != 0:
        for vrstica in row["reactions"]:
            if vrstica['emoji']['name'] not in reakcije2:
                reakcije2.update({vrstica['emoji']['name'] : 1}) 
            else: 
                reakcije2[vrstica['emoji']['name']] += 1

# %%
for index, row in statistikaDf.iterrows(): 
    if len(row["reactions"]) != 0:
        for vrstica in row["reactions"]:
            if vrstica['emoji']['name'] not in reakcije2:
                reakcije2.update({vrstica['emoji']['name'] : 1}) 
            else: 
                reakcije2[vrstica['emoji']['name']] += 1

# %%
# reakcije (emoji-i uporabljeni v 2. semestru) 
reakcije2
# Out:
# {'💯': 55,
#  'feelsWowMan': 182,
#  'weSmart': 240,
#  'HAhaa': 171,
#  'gachiGasm': 54,
#  'everythingokay': 35,
#  '❤': 95,
#  'me_irl2': 59,
#  '👍': 222,
#  '👌': 194,
#  'reee': 67,
#  'puke': 32,
#  '🇸': 38,
#  '🇦': 42,
#  '🇩': 15,
#  'jew': 13,
#  'LUL': 112,
#  '😂': 138,
#  '🍴': 3,
#  '1up': 27,
#  'feelsbadman': 47,
#  'monkaS': 53,
#  'kappa': 8,
#  'feelsHugMan': 68,
#  '👆🏿': 7,
#  'mario': 21,
#  'YEE': 9,
#  'overRustle': 18,
#  '🍕': 1,
#  '👌🏿': 11,
#  'haHAA2': 17,
#  '😭': 13,
#  '😘': 3,
#  '🍪': 2,
#  'feelsamazingman': 91,
#  'tf_do_i_see': 58,
#  '👍🏿': 23,
#  '😡': 6,
#  'thonk': 38,
#  '🔥': 10,
#  'sweatstiny': 46,
#  '🤔': 24,
#  '😢': 23,
#  '👌🏻': 9,
#  '4think': 15,
#  '🇼': 5,
#  '🇹': 24,
#  '🇫': 29,
#  '🔫': 3,
#  '🇳': 39,
#  '🇮': 24,
#  '🇧': 16,
#  '🇵': 18,
#  '🇱': 14,
#  '🇿': 2,
#  '🍆': 9,
#  '👉': 1,
#  '👈': 1,
#  '🤓': 2,
#  '👌🏽': 5,
#  '💛': 3,
#  '💚': 4,
#  '💙': 3,
#  '💜': 1,
#  'PEPE': 51,
#  'GWfroggyFeelsUpMan': 2,
#  'tipsfedora': 119,
#  'hhhehhehe': 17,
# ...

# %% [markdown]
# Ker gledamo najpogosteje uporabljene reakcije, sem tiste, ki so uporabljene manj kot 30-krat odstranil, saj ima reakcija z največ uporabami 500 uporab.

# %%
zbReakcije2 = {}
for key, value in reakcije2.items(): 
    if (value >= 40): 
        if key == '😂':
            zbReakcije2.update({':joy:' : value})
        elif key == '👌': 
            zbReakcije2.update({':ok:' : value})
        elif key == '🤔': 
            zbReakcije2.update({':thinkingfaceemoji:' : value})
        elif key == '😢': 
            zbReakcije2.update({':cryingfaceemoji:' : value})
        elif key == '😄': 
            zbReakcije2.update({':smilingfaceemoji:' : value})
        elif key == '😍': 
            zbReakcije2.update({':hearteyesemoji:' : value})
        elif key == '👀': 
            zbReakcije2.update({':eyesemoji:' : value})
        elif key == '😳': 
            zbReakcije2.update({':flushedfaceemoji:' : value})
        elif key == '🍆': 
            zbReakcije2.update({':eggplant:' : value}) 
        elif key == '❤':
            zbReakcije2.update({':heart:' : value}) 
        elif key == '👍':
            zbReakcije2.update({':thumbsup:' : value}) 
        elif key == '💯':
            zbReakcije2.update({':hundredpoints:' : value}) 
        elif key == '✅': 
            zbReakcije2.update({':whiteheavycheckmark:' : value}) 
        elif key == '🗑': 
            zbReakcije2.update({':wastebasket:' : value}) 
        elif key == '❌': 
            zbReakcije2.update({':crossmarkemoji:' : value}) 
        elif key == '❤️': 
            zbReakcije2.update({':redheartemoji:' : value})
        elif key == '👍🏿': 
            zbReakcije2.update({':blackthumbsup:' : value})
        elif key == '🇦': 
            zbReakcije2.update({':A:' : value})
        elif key == '🇪': 
            zbReakcije2.update({':E:' : value})
        else:
            zbReakcije2.update({key : value})

# %%
# izboljšan slovar reakcij 
zbReakcije2
# Out:
# {':hundredpoints:': 55,
#  'feelsWowMan': 182,
#  'weSmart': 240,
#  'HAhaa': 171,
#  'gachiGasm': 54,
#  ':heart:': 95,
#  'me_irl2': 59,
#  ':thumbsup:': 222,
#  ':ok:': 194,
#  'reee': 67,
#  ':A:': 42,
#  'LUL': 112,
#  ':joy:': 138,
#  'feelsbadman': 47,
#  'monkaS': 53,
#  'feelsHugMan': 68,
#  'feelsamazingman': 91,
#  'tf_do_i_see': 58,
#  'sweatstiny': 46,
#  'PEPE': 51,
#  'tipsfedora': 119,
#  'Wowee': 65,
#  ':whiteheavycheckmark:': 87,
#  'me_irl': 45,
#  ':E:': 50,
#  'omegalul': 43,
#  'pepehands': 100,
#  'honk': 41,
#  'verynice': 60,
#  'GWcorbinHolyFuck': 109,
#  'lekosalute': 500,
#  'Pogey': 55,
#  'kek': 108,
#  'yeeter': 75,
#  'PeepoSad': 89,
#  'vro': 100,
#  ':redheartemoji:': 70,
#  'TopKek': 58,
#  'lekoyes': 164,
#  'lekogun': 52,
#  'kekW': 130,
#  'shid': 49,
#  'leko': 53,
#  'glad': 112}

# %% [markdown]
# **Grafični prikaz podatkov:**

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

csfont = {'fontname':'DejaVu Sans'}

f, ax = plt.subplots(figsize=(27,25)) 

plt.barh(*zip(*zbReakcije2.items()), height=0.7, color="darkblue") 
vr = 0
for key, value in zbReakcije2.items():
    plt.text(value, vr, str(value), fontsize=20)
    vr+=1
plt.title("Porazdelitev reakcij na sporočila (2. semester)", fontsize=40) 
plt.xlabel("Število reakcij", fontsize=30)
plt.ylabel("Reakcija", fontsize=30) 
plt.xticks(fontsize=20, **csfont) 
plt.yticks(fontsize=20)
plt.show()

# %% [markdown]
# Ugotovil sem, da se v drugem semestru reakcije oz. emjoi-ji pogosteje in večkrat uporabljajo. Če primerjamo največjo uporabo emoji-jev v prvem semestru, je ta 157 uporab, v drugem semestru pa kar 500 uporab. V obeh semestrih, se najpogosteje uporablja emoji `:lekosalute:`.
#
# Po mojem mnjenju, se v drugem semestru bolj uporabljajo emoji-ji, zato ker ima Discord takrat več uporabnikov kot v prvem semestru. Na začetku prvega semestra marsi kdo sploh ne ve za ta Discord server, ki ga imamo, zato ga tudi ne uporablja, medtem ko v drugem semestru, Discord server večina študentov že pozna in ga tudi uporablja.
