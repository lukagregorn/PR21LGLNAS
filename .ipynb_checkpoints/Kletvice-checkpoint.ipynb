# %%
# uporabljene knjižnice
import json
import pandas as pd
from dateutil.parser import parse
import datetime
from profanity_filter import ProfanityFilter
import spacy
import matplotlib.pyplot as plt

# %%
# prvi semester
matematika = json.load(open('DATA/matematika.json', encoding="utf8"))
matematikaDf = pd.DataFrame(matematika["messages"]) 

diskretne = json.load(open('DATA/diskretne-strukture.json', encoding="utf8"))
diskretneDf = pd.DataFrame(diskretne["messages"]) 

programiranje1 = json.load(open('DATA/programiranje-1.json', encoding="utf8"))
programiranje1Df = pd.DataFrame(programiranje1["messages"]) 

uvod = json.load(open('DATA/uvod-v-racunalnistvo.json', encoding="utf8"))
uvodDf = pd.DataFrame(uvod["messages"]) 

arhitektura = json.load(open('DATA/racunalniska-arhitektura.json', encoding="utf8"))
arhitekturaDf = pd.DataFrame(arhitektura["messages"])

# %%
# drugi semester 
komunikacije = json.load(open('DATA/racunalniske-komunikacije.json', encoding="utf8"))
komunikacijeDf = pd.DataFrame(komunikacije["messages"]) 

operacijski = json.load(open('DATA/operacijski-sistemi.json', encoding="utf8"))
operacijskiDf = pd.DataFrame(operacijski["messages"]) 

programiranje2 = json.load(open('DATA/programiranje-2.json', encoding="utf8"))
programiranje2Df = pd.DataFrame(programiranje2["messages"]) 

podatkovneBaze = json.load(open('DATA/podatkovne-baze.json', encoding="utf8"))
podatkovneBazeDf = pd.DataFrame(podatkovneBaze["messages"]) 

statistika = json.load(open('DATA/statistika.json', encoding="utf8"))
statistikaDf = pd.DataFrame(statistika["messages"])

# %%
allDf = [matematikaDf, diskretneDf, programiranje1Df, uvodDf, arhitekturaDf,
         komunikacijeDf, operacijskiDf, programiranje2Df, podatkovneBazeDf, statistikaDf]

# %%
for df in allDf:
    df["timestamp"] = df["timestamp"].apply(lambda x: parse(x).date())
    df["profane"] = False

# %%
pf = ProfanityFilter(languages=["en", "sl"])

# %%
arhitekturaDf["profane"] = arhitekturaDf["content"].apply(lambda x: pf.is_profane(x))

# %%
arhitekturaDf['timestamp'] = pd.to_datetime(arhitekturaDf['timestamp'])
arhitekturaDf_grouped = arhitekturaDf.groupby(pd.Grouper(key='timestamp',freq='W'))["profane"].sum()
arhitekturaDf_grouped.plot(figsize=(25, 6))
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
matematikaDf["profane"] = matematikaDf["content"].apply(lambda x: pf.is_profane(x))

# %%
matematikaDf['timestamp'] = pd.to_datetime(matematikaDf['timestamp'])
matematikaDf_grouped = matematikaDf.groupby(pd.Grouper(key='timestamp',freq='W'))["profane"].sum()
matematikaDf_grouped.plot(figsize=(25, 6))
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
diskretneDf["profane"] = diskretneDf["content"].apply(lambda x: pf.is_profane(x))

# %%
diskretneDf['timestamp'] = pd.to_datetime(diskretneDf['timestamp'])
diskretneDf_grouped = diskretneDf.groupby(pd.Grouper(key='timestamp',freq='W'))["profane"].sum()
diskretneDf_grouped.plot(figsize=(25, 6))
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
programiranje1Df["profane"] = programiranje1Df["content"].apply(lambda x: pf.is_profane(x))

# %%
programiranje1Df['timestamp'] = pd.to_datetime(programiranje1Df['timestamp'])
programiranje1Df_grouped = programiranje1Df.groupby(pd.Grouper(key='timestamp',freq='W'))["profane"].sum()
programiranje1Df_grouped.plot(figsize=(25, 6))
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
uvodDf["profane"] = uvodDf["content"].apply(lambda x: pf.is_profane(x))

# %%
uvodDf['timestamp'] = pd.to_datetime(uvodDf['timestamp'])
uvodDf_grouped = uvodDf.groupby(pd.Grouper(key='timestamp',freq='W'))["profane"].sum()
uvodDf_grouped.plot(figsize=(25, 6))
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
komunikacijeDf["profane"] = komunikacijeDf["content"].apply(lambda x: pf.is_profane(x))

# %%
komunikacijeDf['timestamp'] = pd.to_datetime(komunikacijeDf['timestamp'])
komunikacijeDf_grouped = komunikacijeDf.groupby(pd.Grouper(key='timestamp',freq='W'))["profane"].sum()
komunikacijeDf_grouped.plot(figsize=(25, 6))
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
operacijskiDf["profane"] = operacijskiDf["content"].apply(lambda x: pf.is_profane(x))

# %%
operacijskiDf['timestamp'] = pd.to_datetime(operacijskiDf['timestamp'])
operacijskiDf_grouped = operacijskiDf.groupby(pd.Grouper(key='timestamp',freq='W'))["profane"].sum()
operacijskiDf_grouped.plot(figsize=(25, 6))
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
programiranje2Df["profane"] = programiranje2Df["content"].apply(lambda x: pf.is_profane(x))

# %%
programiranje2Df['timestamp'] = pd.to_datetime(programiranje2Df['timestamp'])
programiranje2Df_grouped = programiranje2Df.groupby(pd.Grouper(key='timestamp',freq='W'))["profane"].sum()
programiranje2Df_grouped.plot(figsize=(25, 6))
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
podatkovneBazeDf["profane"] = podatkovneBazeDf["content"].apply(lambda x: pf.is_profane(x))

# %%
podatkovneBazeDf['timestamp'] = pd.to_datetime(podatkovneBazeDf['timestamp'])
podatkovneBazeDf_grouped = podatkovneBazeDf.groupby(pd.Grouper(key='timestamp',freq='W'))["profane"].sum()
podatkovneBazeDf_grouped.plot(figsize=(25, 6))
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
statistikaDf["profane"] = statistikaDf["content"].apply(lambda x: pf.is_profane(x))

# %%
statistikaDf['timestamp'] = pd.to_datetime(statistikaDf['timestamp'])
statistikaDf_grouped = statistikaDf.groupby(pd.Grouper(key='timestamp',freq='W'))["profane"].sum()
statistikaDf_grouped.plot(figsize=(25, 6))
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %% [markdown]
# Iz grafov opazimo, da se število pri prvih petih predmetih močno poveča ob koncu januarja, pri drugih petih predmetih pa ob koncu junija torej v času izpitnega obdobja.
